# %%
# !tar chvfz notebook.tar.gz *
# Out:
# dsc-basic-time-series-models/
# dsc-basic-time-series-models/xru_row.csv
# dsc-basic-time-series-models/exch_rates.csv
# dsc-basic-time-series-models/.learn
# dsc-basic-time-series-models/index.ipynb
# dsc-basic-time-series-models/.git/
# dsc-basic-time-series-models/.git/refs/
# dsc-basic-time-series-models/.git/refs/heads/
# dsc-basic-time-series-models/.git/refs/heads/master
# dsc-basic-time-series-models/.git/refs/remotes/
# dsc-basic-time-series-models/.git/refs/remotes/origin/
# dsc-basic-time-series-models/.git/refs/remotes/origin/HEAD
# dsc-basic-time-series-models/.git/refs/tags/
# dsc-basic-time-series-models/.git/index
# dsc-basic-time-series-models/.git/hooks/
# dsc-basic-time-series-models/.git/hooks/pre-push.sample
# dsc-basic-time-series-models/.git/hooks/pre-applypatch.sample
# dsc-basic-time-series-models/.git/hooks/applypatch-msg.sample
# dsc-basic-time-series-models/.git/hooks/post-update.sample
# dsc-basic-time-series-models/.git/hooks/pre-rebase.sample
# ...
